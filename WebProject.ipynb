# %%
import pandas as pd

filename = '/Users/addiemaggard/Documents/Belmont/Junior2/Data&FileStructures/119/2017-02-14.Sweetwater.json'
#filename = '2017-02-21.Sweetwater.json'
data = pd.read_json(filename)

# %%
data
# Out:
#                                           Description                Price  \
# 0   4-string Electric Violin with Maple Body and N...            $2,298.00
# 1   4-string Electric Violin with Maple Body and N...              $649.00
# 2   5-string Electric Violin with Maple Body and N...              $699.00
# 3                           Description not available  Price not available
# 4   4-string Electric Violin with Maple Body and N...              $649.00
# 5   5-string Electric Violin with Maple Body and N...              $699.00
# 6   4-string Electric Violin with Maple Body, Mapl...            $1,369.00
# 7   4-string Electric Bass with Alder Body, Maple ...              $199.99
# 8   6-string Acoustic-electric Guitar with Solid S...              $329.00
# 9   4-string Electric Violin with Maple Body and N...              $649.00
# 10  5-string Electric Violin with Maple Body and N...              $699.00
# ...

# %%
data.Title
# Out:
# 0                            NS Design CR4 Violin Amber
# 1                         NS Design WAV4 Violin - Black
# 2                         NS Design WAV5 Violin - Black
# 3                                   Title not available
# 4                    NS Design WAV4 Violin - Amberburst
# 5                    NS Design WAV5 Violin - Amberburst
# 6                      NS Design NXTa Violin - Sunburst
# 7                        Yamaha TRBX174 Violin Sunburst
# 8     Epiphone Dove Pro Acoustic-electric - Violin B...
# 9               NS Design WAV4 Violin - Transparent Red
# 10              NS Design WAV5 Violin - Transparent Red
# 11                 Yamaha TRBX204 - Old Violin Sunburst
# 12             Ibanez PF28ECEDVS - Dark Violin Sunburst
# 13               Hofner Ignition Violin Bass - Sunburst
# 14                                  Title not available
# 15           Hofner Contemporary Violin Bass - Sunburst
# 16               Hofner Ignition Violin Bass - Sunburst
# ...

# %%
set(data.Title)
# Out:
# {'Epiphone Dove Pro Acoustic-electric - Violin Burst',
#  'Epiphone Olympic, Masterbilt Century Collection - Violin Burst',
#  "Fender Custom Shop Limited '59 Special Stratocaster Journeyman Relic - Faded Violin Burst",
#  "Fender Custom Shop Limited Edition '50s Thinline Telecaster Relic, All Rosewood Neck - Faded Violin Burst",
#  "Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Cadillac Green",
#  "Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Candy Apple Red",
#  "Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Gold Top",
#  "Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Orange",
#  "Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Purple",
#  "Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Silverburst",
#  "Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Tobacco Sunburst",
#  'Hofner Contemporary Violin Bass - Sunburst',
#  'Hofner HCT-500/1 Contemporary Series Violin Bass - Antique Brown Sunburst',
# ...

# %%
i = 0
for stuff in data.Title:
    if('Bass') in stuff:
        print(stuff)
        print()
        i += 1
print(i)
# Out:
# Hofner Ignition Violin Bass - Sunburst
#
# Hofner Contemporary Violin Bass - Sunburst
#
# Hofner Ignition Violin Bass - Sunburst
#
# Hofner Vintage '64 Violin Bass - Sunburst
#
# Hofner Vintage '62 Violin Bass - Sunburst
#
# Hofner Ignition Violin Bass - Translucent Black
#
# Hofner HCT-500/1 Contemporary Series Violin Bass - Black
#
# Hofner HCT-500/1 Contemporary Series Violin Bass, Left handed - Black
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Cadillac Green
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Purple
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Tobacco Sunburst
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Silverburst
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Candy Apple Red
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Orange
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Gold Top
#
# ...

# %%
i = 0
for stuff in data.Title:
    if('2') in stuff:
        print(stuff)
        print()
        i += 1
print(i)
# Out:
# Yamaha TRBX204 - Old Violin Sunburst
#
# Ibanez PF28ECEDVS - Dark Violin Sunburst
#
# PRS CE 24 - Violin Amber Sunburst
#
# Ibanez AR Prestige AR2619 - Antique Violin
#
# Ibanez AR Series AR725 - Violin Sunburst
#
# Ibanez AEG 12-String - Dark Violin Sunburst
#
# PRS S2 Custom 24 - Violin Amber Sunburst
#
# Ibanez AR Series AR420 - Violin Sunburst
#
# Hofner Vintage '62 Violin Bass - Sunburst
#
# PRS S2 Custom 22 - Violin Amber Sunburst
#
# PRS S2 Singlecut - Violin Amber Sunburst
#
# PRS S2 Custom 22 Semi-hollow - Violin Amber Sunburst
#
# PRS S2 Singlecut Semi-hollow - Violin Amber Sunburst
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Cadillac Green
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Purple
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Tobacco Sunburst
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Silverburst
#
# Hofner '62 Custom Shop Violin Bass, Sweetwater Custom - Candy Apple Red
#
# ...

# %%
i = 0
for stuff in data.Title:
    if('4') in stuff:
        print(stuff)
        print()
        i += 1
print(i)
# Out:
# NS Design CR4 Violin Amber
#
# NS Design WAV4 Violin - Black
#
# NS Design WAV4 Violin - Amberburst
#
# Yamaha TRBX174 Violin Sunburst
#
# NS Design WAV4 Violin - Transparent Red
#
# Yamaha TRBX204 - Old Violin Sunburst
#
# PRS CE 24 - Violin Amber Sunburst
#
# Hofner Vintage '64 Violin Bass - Sunburst
#
# PRS S2 Custom 24 - Violin Amber Sunburst
#
# Ibanez AR Series AR420 - Violin Sunburst
#
# 10

# %%
data.Price
# Out:
# 0               $2,298.00
# 1                 $649.00
# 2                 $699.00
# 3     Price not available
# 4                 $649.00
# 5                 $699.00
# 6               $1,369.00
# 7                 $199.99
# 8                 $329.00
# 9                 $649.00
# 10                $699.00
# 11                $279.99
# 12                $299.99
# 13                $469.99
# 14    Price not available
# 15                $879.99
# 16                $279.00
# 17                $359.99
# 18                $649.99
# 19              $1,999.00
# 20              $2,299.99
# 21                $899.99
# 22              $2,869.99
# 23                $299.99
# 24              $1,449.00
# 25                $649.99
# 26              $2,869.99
# 27              $1,449.00
# 28    Price not available
# 29                $279.00
# 30              $1,489.00
# 31              $1,679.00
# 32                $599.00
# 33                $548.00
# 34              $3,950.00
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.Description
# Out:
# 0     4-string Electric Violin with Maple Body and N...
# 1     4-string Electric Violin with Maple Body and N...
# 2     5-string Electric Violin with Maple Body and N...
# 3                             Description not available
# 4     4-string Electric Violin with Maple Body and N...
# 5     5-string Electric Violin with Maple Body and N...
# 6     4-string Electric Violin with Maple Body, Mapl...
# 7     4-string Electric Bass with Alder Body, Maple ...
# 8     6-string Acoustic-electric Guitar with Solid S...
# 9     4-string Electric Violin with Maple Body and N...
# 10    5-string Electric Violin with Maple Body and N...
# 11    4-string Electric Bass with Basswood Body, Map...
# 12    Acoustic-electric Guitar with Flame Maple Top,...
# 13    4-string Hollowbody Electric Bass with Spruce ...
# 14                            Description not available
# 15    4-string Semi-hollowbody Electric Bass with Sp...
# 16    4-string Hollowbody Electric Bass with Spruce ...
# ...

# %%
i = 0
for stuff in data.Description:
    if('Polar') in stuff:
        print(stuff)
        print()
        i += 1
print(i)
# Out:
# 4-string Electric Violin with Maple Body and Neck, Ebony Fingerboard, Active Polar Pickup System Electronics with Dual Mode Preamp, and Hardshell Case - Amber
#
# 4-string Electric Violin with Maple Body and Neck, Ebony Fingerboard, Polar Pickup System Electronics, and Hard Foam Case - Black
#
# 5-string Electric Violin with Maple Body and Neck, Ebony Fingerboard, Polar Pickup System Electronics, and Hard Foam Case - Black
#
# 4-string Electric Violin with Maple Body and Neck, Ebony Fingerboard, Polar Pickup System Electronics, and Hard Foam Case - Amberburst
#
# 5-string Electric Violin with Maple Body and Neck, Ebony Fingerboard, Polar Pickup System Electronics, and Hard Foam Case - Amberburst
#
# 4-string Electric Violin with Maple Body, Maple Neck, Richlite Fingerboard, NS Polar Pickup System, and Active/Passive Electronics - Sunburst
#
# 4-string Electric Violin with Maple Body and Neck, Ebony Fingerboard, Polar Pickup System Electronics, and Hard Foam Case - Transparent Red
#
# ...
